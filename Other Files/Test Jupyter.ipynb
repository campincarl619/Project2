# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Create Engine and Pass in MySQL Connection
engine = create_engine("mysql://root:password@localhost:3306/schooldata")
conn = engine.connect()
schoolsStuff = pd.read_sql("SELECT * FROM `school_data_all`", conn)
# Out:
# C:\Anaconda\lib\site-packages\pymysql\cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
schoolsStuff.head()
# Out:
#     ?Unique_ID  Year  Unit_ID                     Institution_Name  \
# 0  2010_100654  2010   100654             Alabama A & M University
# 1  2010_100663  2010   100663  University of Alabama at Birmingham
# 2  2010_100690  2010   100690                   Amridge University
# 3  2010_100706  2010   100706  University of Alabama in Huntsville
# 4  2010_100724  2010   100724             Alabama State University
#
#          City State    Zip  Region Region_Name   Latitude  Longitude  \
# 0      Normal    AL  35762       5   Southeast  34.783368 -86.568502
# 1  Birmingham    AL  35294       5   Southeast  33.502230 -86.809170
# 2  Montgomery    AL  36117       5   Southeast  32.362609 -86.174010
# 3  Huntsville    AL  35899       5   Southeast  34.722818 -86.638420
# 4  Montgomery    AL  36104       5   Southeast  32.364317 -86.295677
#
#    Admission_Rate  SAT_Avg  Tuition_Cost  Student_Loan_Percentage  Age_Entry  \
# 0          0.5129      849         13762                 0.938224  20.983784
# 1          0.8243     1108         18003                 0.913645  23.633528
# 2          0.7143       -1         20700                 0.935103  32.828909
# 3          0.6614     1163         17064                 0.906414  23.933844
# 4          0.4372      742         14390                 0.924936  20.910305
#
#    Male_Percentage  Female_Percentage  Number_Grad
# 0           0.4771             0.5229          874
# 1           0.4170             0.5830         6515
# 2           0.4649             0.5351          379
# 3           0.5297             0.4703         1609
# 4           0.4097             0.5903          823

# %%
schoolsStuff.set_index("?Unique_ID", drop = True, inplace = True)
schoolsStuff.head()
# Out:
#              Year  Unit_ID                     Institution_Name        City  \
# ?Unique_ID
# 2010_100654  2010   100654             Alabama A & M University      Normal
# 2010_100663  2010   100663  University of Alabama at Birmingham  Birmingham
# 2010_100690  2010   100690                   Amridge University  Montgomery
# 2010_100706  2010   100706  University of Alabama in Huntsville  Huntsville
# 2010_100724  2010   100724             Alabama State University  Montgomery
#
#             State    Zip  Region Region_Name   Latitude  Longitude  \
# ?Unique_ID
# 2010_100654    AL  35762       5   Southeast  34.783368 -86.568502
# 2010_100663    AL  35294       5   Southeast  33.502230 -86.809170
# 2010_100690    AL  36117       5   Southeast  32.362609 -86.174010
# 2010_100706    AL  35899       5   Southeast  34.722818 -86.638420
# 2010_100724    AL  36104       5   Southeast  32.364317 -86.295677
#
#              Admission_Rate  SAT_Avg  Tuition_Cost  Student_Loan_Percentage  \
# ?Unique_ID
# 2010_100654          0.5129      849         13762                 0.938224
# 2010_100663          0.8243     1108         18003                 0.913645
# 2010_100690          0.7143       -1         20700                 0.935103
# 2010_100706          0.6614     1163         17064                 0.906414
# 2010_100724          0.4372      742         14390                 0.924936
#
#              Age_Entry  Male_Percentage  Female_Percentage  Number_Grad
# ?Unique_ID
# 2010_100654  20.983784           0.4771             0.5229          874
# 2010_100663  23.633528           0.4170             0.5830         6515
# 2010_100690  32.828909           0.4649             0.5351          379
# 2010_100706  23.933844           0.5297             0.4703         1609
# 2010_100724  20.910305           0.4097             0.5903          823

# %%
dictionary = schoolsStuff.to_dict(orient = "index")
dictionary
# Out:
# {'2010_100654': {'Admission_Rate': 0.5129,
#   'Age_Entry': 20.98378378,
#   'City': 'Normal',
#   'Female_Percentage': 0.5229,
#   'Institution_Name': 'Alabama A & M University',
#   'Latitude': 34.783368,
#   'Longitude': -86.568502,
#   'Male_Percentage': 0.4771,
#   'Number_Grad': 874,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 849,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.938223938,
#   'Tuition_Cost': 13762,
#   'Unit_ID': 100654,
#   'Year': 2010,
#   'Zip': 35762},
#  '2010_100663': {'Admission_Rate': 0.8243,
#   'Age_Entry': 23.63352827,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.583,
#   'Institution_Name': 'University of Alabama at Birmingham',
#   'Latitude': 33.50223,
#   'Longitude': -86.80917,
#   'Male_Percentage': 0.417,
#   'Number_Grad': 6515,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1108,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.913645224,
#   'Tuition_Cost': 18003,
#   'Unit_ID': 100663,
#   'Year': 2010,
#   'Zip': 35294},
#  '2010_100690': {'Admission_Rate': 0.7143,
#   'Age_Entry': 32.82890856,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.5351,
#   'Institution_Name': 'Amridge University',
#   'Latitude': 32.362609,
#   'Longitude': -86.17401,
#   'Male_Percentage': 0.4649,
#   'Number_Grad': 379,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.935103245,
#   'Tuition_Cost': 20700,
#   'Unit_ID': 100690,
#   'Year': 2010,
#   'Zip': 36117},
#  '2010_100706': {'Admission_Rate': 0.6614,
#   'Age_Entry': 23.93384429,
#   'City': 'Huntsville',
#   'Female_Percentage': 0.4703,
#   'Institution_Name': 'University of Alabama in Huntsville',
#   'Latitude': 34.722818,
#   'Longitude': -86.63842,
#   'Male_Percentage': 0.5297,
#   'Number_Grad': 1609,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1163,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.906413877,
#   'Tuition_Cost': 17064,
#   'Unit_ID': 100706,
#   'Year': 2010,
#   'Zip': 35899},
#  '2010_100724': {'Admission_Rate': 0.4372,
#   'Age_Entry': 20.91030534,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.5903,
#   'Institution_Name': 'Alabama State University',
#   'Latitude': 32.364317,
#   'Longitude': -86.295677,
#   'Male_Percentage': 0.4097,
#   'Number_Grad': 823,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 742,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.924936387,
#   'Tuition_Cost': 14390,
#   'Unit_ID': 100724,
#   'Year': 2010,
#   'Zip': 36104},
#  '2010_100751': {'Admission_Rate': 0.5358,
#   'Age_Entry': 21.43538861,
#   'City': 'Tuscaloosa',
#   'Female_Percentage': 0.5237,
#   'Institution_Name': 'The University of Alabama',
#   'Latitude': 33.2144,
#   'Longitude': -87.545766,
#   'Male_Percentage': 0.4763,
#   'Number_Grad': 5245,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1155,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.94129459,
#   'Tuition_Cost': 21565,
#   'Unit_ID': 100751,
#   'Year': 2010,
#   'Zip': 35487},
#  '2010_100760': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.60836137,
#   'City': 'Alexander City',
#   'Female_Percentage': 0.6467,
#   'Institution_Name': 'Central Alabama Community College',
#   'Latitude': 32.924429,
#   'Longitude': -85.94653,
#   'Male_Percentage': 0.3533,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.519461797,
#   'Tuition_Cost': 7109,
#   'Unit_ID': 100760,
#   'Year': 2010,
#   'Zip': 35010},
#  '2010_100812': {'Admission_Rate': -1.0,
#   'Age_Entry': 30.8776542,
#   'City': 'Athens',
#   'Female_Percentage': 0.6561,
#   'Institution_Name': 'Athens State University',
#   'Latitude': 34.805625,
#   'Longitude': -86.96514,
#   'Male_Percentage': 0.3439,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.807886754,
#   'Tuition_Cost': -1,
#   'Unit_ID': 100812,
#   'Year': 2010,
#   'Zip': 35611},
#  '2010_100830': {'Admission_Rate': 0.9503,
#   'Age_Entry': 23.77870564,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.6213,
#   'Institution_Name': 'Auburn University at Montgomery',
#   'Latitude': 32.369939,
#   'Longitude': -86.177351,
#   'Male_Percentage': 0.3787,
#   'Number_Grad': 988,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 970,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.922755741,
#   'Tuition_Cost': 14367,
#   'Unit_ID': 100830,
#   'Year': 2010,
#   'Zip': 36117},
#  '2010_100858': {'Admission_Rate': 0.7867,
#   'Age_Entry': 20.52697906,
#   'City': 'Auburn',
#   'Female_Percentage': 0.4858,
#   'Institution_Name': 'Auburn University',
#   'Latitude': 32.604685,
#   'Longitude': -85.482782,
#   'Male_Percentage': 0.5142,
#   'Number_Grad': 4857,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1221,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.930954917,
#   'Tuition_Cost': 19490,
#   'Unit_ID': 100858,
#   'Year': 2010,
#   'Zip': 36849},
#  '2010_100937': {'Admission_Rate': 0.6649,
#   'Age_Entry': 19.83302412,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.4938,
#   'Institution_Name': 'Birmingham Southern College',
#   'Latitude': 33.515453,
#   'Longitude': -86.853636,
#   'Male_Percentage': 0.5062,
#   'Number_Grad': 21,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1192,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.959183674,
#   'Tuition_Cost': 38205,
#   'Unit_ID': 100937,
#   'Year': 2010,
#   'Zip': 35254},
#  '2010_101028': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.92069214,
#   'City': 'Phenix City',
#   'Female_Percentage': 0.6491,
#   'Institution_Name': 'Chattahoochee Valley Community College',
#   'Latitude': 32.42391,
#   'Longitude': -85.031485,
#   'Male_Percentage': 0.3509,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.06705119,
#   'Tuition_Cost': 5540,
#   'Unit_ID': 101028,
#   'Year': 2010,
#   'Zip': 36869},
#  '2010_101073': {'Admission_Rate': -1.0,
#   'Age_Entry': 21.84131737,
#   'City': 'Selma',
#   'Female_Percentage': 0.431,
#   'Institution_Name': 'Concordia College Alabama',
#   'Latitude': 32.42443,
#   'Longitude': -87.023531,
#   'Male_Percentage': 0.569,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.863772455,
#   'Tuition_Cost': 13210,
#   'Unit_ID': 101073,
#   'Year': 2010,
#   'Zip': 36701},
#  '2010_101116': {'Admission_Rate': 0.9273,
#   'Age_Entry': 31.75098255,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.7262,
#   'Institution_Name': 'South University-Montgomery',
#   'Latitude': 32.342684,
#   'Longitude': -86.216488,
#   'Male_Percentage': 0.2738,
#   'Number_Grad': 57,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.857817293,
#   'Tuition_Cost': 27418,
#   'Unit_ID': 101116,
#   'Year': 2010,
#   'Zip': 36116},
#  '2010_101143': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.67510354,
#   'City': 'Enterprise',
#   'Female_Percentage': 0.3929,
#   'Institution_Name': 'Enterprise State Community College',
#   'Latitude': 31.297496,
#   'Longitude': -85.836956,
#   'Male_Percentage': 0.6071,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.460653475,
#   'Tuition_Cost': 9146,
#   'Unit_ID': 101143,
#   'Year': 2010,
#   'Zip': 36330},
#  '2010_101161': {'Admission_Rate': -1.0,
#   'Age_Entry': 24.53665536,
#   'City': 'Bay Minette',
#   'Female_Percentage': 0.6326,
#   'Institution_Name': 'James H Faulkner State Community College',
#   'Latitude': 30.852045,
#   'Longitude': -87.779758,
#   'Male_Percentage': 0.3674,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.540829637,
#   'Tuition_Cost': 7987,
#   'Unit_ID': 101161,
#   'Year': 2010,
#   'Zip': 36507},
#  '2010_101189': {'Admission_Rate': 0.5117,
#   'Age_Entry': 29.69933185,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.623,
#   'Institution_Name': 'Faulkner University',
#   'Latitude': 32.384181,
#   'Longitude': -86.21641,
#   'Male_Percentage': 0.377,
#   'Number_Grad': 564,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1052,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.935857461,
#   'Tuition_Cost': 24105,
#   'Unit_ID': 101189,
#   'Year': 2010,
#   'Zip': 36109},
#  '2010_101240': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.00967926,
#   'City': 'Gadsden',
#   'Female_Percentage': 0.6217,
#   'Institution_Name': 'Gadsden State Community College',
#   'Latitude': 33.991866,
#   'Longitude': -85.991299,
#   'Male_Percentage': 0.3783,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 9628,
#   'Unit_ID': 101240,
#   'Year': 2010,
#   'Zip': 35903},
#  '2010_101286': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.96916812,
#   'City': 'Dothan',
#   'Female_Percentage': 0.6801,
#   'Institution_Name': 'George C Wallace State Community College-Dothan',
#   'Latitude': 31.316086,
#   'Longitude': -85.46355,
#   'Male_Percentage': 0.3199,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 7168,
#   'Unit_ID': 101286,
#   'Year': 2010,
#   'Zip': 36303},
#  '2010_101295': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.08686869,
#   'City': 'Hanceville',
#   'Female_Percentage': 0.63,
#   'Institution_Name': 'George C Wallace State Community College-Hanceville',
#   'Latitude': 34.07341,
#   'Longitude': -86.781745,
#   'Male_Percentage': 0.37,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.644219978,
#   'Tuition_Cost': 9743,
#   'Unit_ID': 101295,
#   'Year': 2010,
#   'Zip': 35077},
#  '2010_101301': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.01466737,
#   'City': 'Selma',
#   'Female_Percentage': 0.6787,
#   'Institution_Name': 'George C Wallace State Community College-Selma',
#   'Latitude': 32.445611,
#   'Longitude': -87.01324,
#   'Male_Percentage': 0.3213,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 14339,
#   'Unit_ID': 101301,
#   'Year': 2010,
#   'Zip': 36703},
#  '2010_101365': {'Admission_Rate': 0.7907,
#   'Age_Entry': 31.23799859,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.6755,
#   'Institution_Name': 'Herzing University-Birmingham',
#   'Latitude': 33.468105,
#   'Longitude': -86.832299,
#   'Male_Percentage': 0.3245,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.828715143,
#   'Tuition_Cost': 21272,
#   'Unit_ID': 101365,
#   'Year': 2010,
#   'Zip': 35209},
#  '2010_101435': {'Admission_Rate': 0.6217,
#   'Age_Entry': 23.70756063,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.5091,
#   'Institution_Name': 'Huntingdon College',
#   'Latitude': 32.350939,
#   'Longitude': -86.285313,
#   'Male_Percentage': 0.4909,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1026,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.938659059,
#   'Tuition_Cost': 28724,
#   'Unit_ID': 101435,
#   'Year': 2010,
#   'Zip': 36106},
#  '2010_101453': {'Admission_Rate': -1.0,
#   'Age_Entry': 32.29032258,
#   'City': 'Florence',
#   'Female_Percentage': 0.2,
#   'Institution_Name': 'Heritage Christian University',
#   'Latitude': 34.859089,
#   'Longitude': -87.662062,
#   'Male_Percentage': 0.8,
#   'Number_Grad': 28,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 14639,
#   'Unit_ID': 101453,
#   'Year': 2010,
#   'Zip': 35630},
#  '2010_101462': {'Admission_Rate': -1.0,
#   'Age_Entry': 29.28609626,
#   'City': 'Huntsville',
#   'Female_Percentage': 0.6199,
#   'Institution_Name': 'J F Drake State Community and Technical College',
#   'Latitude': 34.772116,
#   'Longitude': -86.573817,
#   'Male_Percentage': 0.3801,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 10428,
#   'Unit_ID': 101462,
#   'Year': 2010,
#   'Zip': 35811},
#  '2010_101480': {'Admission_Rate': 0.8397,
#   'Age_Entry': 23.48484095,
#   'City': 'Jacksonville',
#   'Female_Percentage': 0.5756,
#   'Institution_Name': 'Jacksonville State University',
#   'Latitude': 33.822128,
#   'Longitude': -85.766644,
#   'Male_Percentage': 0.4244,
#   'Number_Grad': 1404,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1001,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.903578529,
#   'Tuition_Cost': 16378,
#   'Unit_ID': 101480,
#   'Year': 2010,
#   'Zip': 36265},
#  '2010_101499': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.73638132,
#   'City': 'Brewton',
#   'Female_Percentage': 0.5982,
#   'Institution_Name': 'Jefferson Davis Community College',
#   'Latitude': 31.101995,
#   'Longitude': -87.085829,
#   'Male_Percentage': 0.4018,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 7359,
#   'Unit_ID': 101499,
#   'Year': 2010,
#   'Zip': 36426},
#  '2010_101505': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.05957287,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.6046,
#   'Institution_Name': 'Jefferson State Community College',
#   'Latitude': 33.652439,
#   'Longitude': -86.707387,
#   'Male_Percentage': 0.3954,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.513300862,
#   'Tuition_Cost': 12048,
#   'Unit_ID': 101505,
#   'Year': 2010,
#   'Zip': 35215},
#  '2010_101514': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.99524276,
#   'City': 'Tanner',
#   'Female_Percentage': 0.5611,
#   'Institution_Name': 'John C Calhoun State Community College',
#   'Latitude': 34.65428,
#   'Longitude': -86.949131,
#   'Male_Percentage': 0.4389,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.500909473,
#   'Tuition_Cost': 8937,
#   'Unit_ID': 101514,
#   'Year': 2010,
#   'Zip': 35671},
#  '2010_101541': {'Admission_Rate': 0.8154,
#   'Age_Entry': 21.62234043,
#   'City': 'Marion',
#   'Female_Percentage': 0.971,
#   'Institution_Name': 'Judson College',
#   'Latitude': 32.630526,
#   'Longitude': -87.316127,
#   'Male_Percentage': 0.029,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1008,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.930851064,
#   'Tuition_Cost': 24537,
#   'Unit_ID': 101541,
#   'Year': 2010,
#   'Zip': 36756},
#  '2010_101569': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.5623613,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.6152,
#   'Institution_Name': 'Lawson State Community College-Birmingham Campus',
#   'Latitude': 33.451673,
#   'Longitude': -86.890234,
#   'Male_Percentage': 0.3848,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 10421,
#   'Unit_ID': 101569,
#   'Year': 2010,
#   'Zip': 35221},
#  '2010_101587': {'Admission_Rate': 0.4052,
#   'Age_Entry': 25.6343949,
#   'City': 'Livingston',
#   'Female_Percentage': 0.585,
#   'Institution_Name': 'University of West Alabama',
#   'Latitude': 32.59244,
#   'Longitude': -88.186077,
#   'Male_Percentage': 0.415,
#   'Number_Grad': 3179,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 990,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.922292994,
#   'Tuition_Cost': 14833,
#   'Unit_ID': 101587,
#   'Year': 2010,
#   'Zip': 35470},
#  '2010_101602': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.54378819,
#   'City': 'Andalusia',
#   'Female_Percentage': 0.6793,
#   'Institution_Name': 'Lurleen B Wallace Community College',
#   'Latitude': 31.322947,
#   'Longitude': -86.452262,
#   'Male_Percentage': 0.3207,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 9449,
#   'Unit_ID': 101602,
#   'Year': 2010,
#   'Zip': 36420},
#  '2010_101648': {'Admission_Rate': 0.4407,
#   'Age_Entry': 19.71685393,
#   'City': 'Marion',
#   'Female_Percentage': 0.1583,
#   'Institution_Name': 'Marion Military Institute',
#   'Latitude': 32.622359,
#   'Longitude': -87.317998,
#   'Male_Percentage': 0.8417,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1029,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.831460674,
#   'Tuition_Cost': 17620,
#   'Unit_ID': 101648,
#   'Year': 2010,
#   'Zip': 36756},
#  '2010_101675': {'Admission_Rate': -1.0,
#   'Age_Entry': 22.0389313,
#   'City': 'Fairfield',
#   'Female_Percentage': 0.5217,
#   'Institution_Name': 'Miles College',
#   'Latitude': 33.481306,
#   'Longitude': -86.908605,
#   'Male_Percentage': 0.4783,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.966412214,
#   'Tuition_Cost': 18669,
#   'Unit_ID': 101675,
#   'Year': 2010,
#   'Zip': 35064},
#  '2010_101693': {'Admission_Rate': 0.746,
#   'Age_Entry': 25.79296482,
#   'City': 'Mobile',
#   'Female_Percentage': 0.6845,
#   'Institution_Name': 'University of Mobile',
#   'Latitude': 30.793247,
#   'Longitude': -88.128934,
#   'Male_Percentage': 0.3155,
#   'Number_Grad': 193,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1064,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.952763819,
#   'Tuition_Cost': 26950,
#   'Unit_ID': 101693,
#   'Year': 2010,
#   'Zip': 36613},
#  '2010_101709': {'Admission_Rate': 0.723,
#   'Age_Entry': 22.61827498,
#   'City': 'Montevallo',
#   'Female_Percentage': 0.6651,
#   'Institution_Name': 'University of Montevallo',
#   'Latitude': 33.10625,
#   'Longitude': -86.865099,
#   'Male_Percentage': 0.3349,
#   'Number_Grad': 533,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1070,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.918018787,
#   'Tuition_Cost': 15460,
#   'Unit_ID': 101709,
#   'Year': 2010,
#   'Zip': 35115},
#  '2010_101736': {'Admission_Rate': -1.0,
#   'Age_Entry': 24.87294421,
#   'City': 'Muscle Shoals',
#   'Female_Percentage': 0.5951,
#   'Institution_Name': 'Northwest-Shoals Community College',
#   'Latitude': 34.739567,
#   'Longitude': -87.67733,
#   'Male_Percentage': 0.4049,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.433731055,
#   'Tuition_Cost': 10115,
#   'Unit_ID': 101736,
#   'Year': 2010,
#   'Zip': 35661},
#  '2010_101879': {'Admission_Rate': 0.8685,
#   'Age_Entry': 22.72334773,
#   'City': 'Florence',
#   'Female_Percentage': 0.575,
#   'Institution_Name': 'University of North Alabama',
#   'Latitude': 34.80658,
#   'Longitude': -87.680999,
#   'Male_Percentage': 0.425,
#   'Number_Grad': 1048,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1010,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.866821654,
#   'Tuition_Cost': 12123,
#   'Unit_ID': 101879,
#   'Year': 2010,
#   'Zip': 35632},
#  '2010_101897': {'Admission_Rate': -1.0,
#   'Age_Entry': 27.72768362,
#   'City': 'Rainsville',
#   'Female_Percentage': 0.6314,
#   'Institution_Name': 'Northeast Alabama Community College',
#   'Latitude': 34.545471,
#   'Longitude': -85.911664,
#   'Male_Percentage': 0.3686,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.248587571,
#   'Tuition_Cost': 6350,
#   'Unit_ID': 101897,
#   'Year': 2010,
#   'Zip': 35986},
#  '2010_101912': {'Admission_Rate': 0.5112,
#   'Age_Entry': 22.00687623,
#   'City': 'Huntsville',
#   'Female_Percentage': 0.5693,
#   'Institution_Name': 'Oakwood University',
#   'Latitude': 34.756628,
#   'Longitude': -86.661628,
#   'Male_Percentage': 0.4307,
#   'Number_Grad': 48,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 938,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.945972495,
#   'Tuition_Cost': 31700,
#   'Unit_ID': 101912,
#   'Year': 2010,
#   'Zip': 35896},
#  '2010_101949': {'Admission_Rate': -1.0,
#   'Age_Entry': 24.69859985,
#   'City': 'Monroeville',
#   'Female_Percentage': 0.6704,
#   'Institution_Name': 'Alabama Southern Community College',
#   'Latitude': 31.488925,
#   'Longitude': -87.326352,
#   'Male_Percentage': 0.3296,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 9204,
#   'Unit_ID': 101949,
#   'Year': 2010,
#   'Zip': 36460},
#  '2010_101958': {'Admission_Rate': -1.0,
#   'Age_Entry': 32.91489362,
#   'City': 'Elmhurst',
#   'Female_Percentage': 0.9535,
#   'Institution_Name': 'Prince Institute-Southeast',
#   'Latitude': 41.928952,
#   'Longitude': -87.962922,
#   'Male_Percentage': 0.0465,
#   'Number_Grad': -1,
#   'Region': 3,
#   'Region_Name': 'Great Lakes',
#   'SAT_Avg': -1,
#   'State': 'IL',
#   'Student_Loan_Percentage': 0.879432624,
#   'Tuition_Cost': 23965,
#   'Unit_ID': 101958,
#   'Year': 2010,
#   'Zip': 60126},
#  '2010_101994': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.86933333,
#   'City': 'Evergreen',
#   'Female_Percentage': 0.6122,
#   'Institution_Name': 'Reid State Technical College',
#   'Latitude': 31.46071,
#   'Longitude': -86.964486,
#   'Male_Percentage': 0.3878,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 6663,
#   'Unit_ID': 101994,
#   'Year': 2010,
#   'Zip': 36401},
#  '2010_102030': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.16861979,
#   'City': 'Mobile',
#   'Female_Percentage': 0.6636,
#   'Institution_Name': 'Bishop State Community College',
#   'Latitude': 30.693972,
#   'Longitude': -88.056982,
#   'Male_Percentage': 0.3364,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 7317,
#   'Unit_ID': 102030,
#   'Year': 2010,
#   'Zip': 36603},
#  '2010_102049': {'Admission_Rate': 0.8669,
#   'Age_Entry': 21.03842049,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.6364,
#   'Institution_Name': 'Samford University',
#   'Latitude': 33.464578,
#   'Longitude': -86.790932,
#   'Male_Percentage': 0.3636,
#   'Number_Grad': 1777,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1172,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.919957311,
#   'Tuition_Cost': 32527,
#   'Unit_ID': 102049,
#   'Year': 2010,
#   'Zip': 35229},
#  '2010_102058': {'Admission_Rate': -1.0,
#   'Age_Entry': 29.10469799,
#   'City': 'Selma',
#   'Female_Percentage': 0.5873,
#   'Institution_Name': 'Selma University',
#   'Latitude': 32.420358,
#   'Longitude': -87.033826,
#   'Male_Percentage': 0.4127,
#   'Number_Grad': 31,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.71409396,
#   'Tuition_Cost': 6147,
#   'Unit_ID': 102058,
#   'Year': 2010,
#   'Zip': 36701},
#  '2010_102067': {'Admission_Rate': -1.0,
#   'Age_Entry': 23.74011446,
#   'City': 'Tuscaloosa',
#   'Female_Percentage': 0.5395,
#   'Institution_Name': 'Shelton State Community College',
#   'Latitude': 33.120531,
#   'Longitude': -87.56148,
#   'Male_Percentage': 0.4605,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 10195,
#   'Unit_ID': 102067,
#   'Year': 2010,
#   'Zip': 35405},
#  '2010_102076': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.98731884,
#   'City': 'Boaz',
#   'Female_Percentage': 0.6409,
#   'Institution_Name': 'Snead State Community College',
#   'Latitude': 34.201247,
#   'Longitude': -86.169479,
#   'Male_Percentage': 0.3591,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.11352657,
#   'Tuition_Cost': 8167,
#   'Unit_ID': 102076,
#   'Year': 2010,
#   'Zip': 35957},
#  '2010_102094': {'Admission_Rate': 0.8645,
#   'Age_Entry': 23.42845258,
#   'City': 'Mobile',
#   'Female_Percentage': 0.5686,
#   'Institution_Name': 'University of South Alabama',
#   'Latitude': 30.695081,
#   'Longitude': -88.18189,
#   'Male_Percentage': 0.4314,
#   'Number_Grad': 3118,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1010,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.912312812,
#   'Tuition_Cost': 13338,
#   'Unit_ID': 102094,
#   'Year': 2010,
#   'Zip': 36688},
#  '2010_102234': {'Admission_Rate': 0.5307,
#   'Age_Entry': 21.37209302,
#   'City': 'Mobile',
#   'Female_Percentage': 0.6216,
#   'Institution_Name': 'Spring Hill College',
#   'Latitude': 30.694751,
#   'Longitude': -88.138199,
#   'Male_Percentage': 0.3784,
#   'Number_Grad': 218,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1087,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.94254446,
#   'Tuition_Cost': 37992,
#   'Unit_ID': 102234,
#   'Year': 2010,
#   'Zip': 36608},
#  '2010_102261': {'Admission_Rate': 0.8696,
#   'Age_Entry': 29.98496241,
#   'City': 'Birmingham',
#   'Female_Percentage': 0.4947,
#   'Institution_Name': 'Southeastern Bible College',
#   'Latitude': 33.378935,
#   'Longitude': -86.749045,
#   'Male_Percentage': 0.5053,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 970,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 17692,
#   'Unit_ID': 102261,
#   'Year': 2010,
#   'Zip': 35244},
#  '2010_102270': {'Admission_Rate': 0.4855,
#   'Age_Entry': 20.26426799,
#   'City': 'Tuscaloosa',
#   'Female_Percentage': 0.5616,
#   'Institution_Name': 'Stillman College',
#   'Latitude': 33.199228,
#   'Longitude': -87.585242,
#   'Male_Percentage': 0.4384,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 831,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.955334988,
#   'Tuition_Cost': 23198,
#   'Unit_ID': 102270,
#   'Year': 2010,
#   'Zip': 35401},
#  '2010_102298': {'Admission_Rate': -1.0,
#   'Age_Entry': 22.47311828,
#   'City': 'Talladega',
#   'Female_Percentage': 0.5722,
#   'Institution_Name': 'Talladega College',
#   'Latitude': 33.434258,
#   'Longitude': -86.113675,
#   'Male_Percentage': 0.4278,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.797491039,
#   'Tuition_Cost': 17047,
#   'Unit_ID': 102298,
#   'Year': 2010,
#   'Zip': 35160},
#  '2010_102313': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.70559611,
#   'City': 'Montgomery',
#   'Female_Percentage': 0.5195,
#   'Institution_Name': 'H Councill Trenholm State Community College',
#   'Latitude': 32.350109,
#   'Longitude': -86.343057,
#   'Male_Percentage': 0.4805,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 11970,
#   'Unit_ID': 102313,
#   'Year': 2010,
#   'Zip': 36108},
#  '2010_102368': {'Admission_Rate': 0.6951,
#   'Age_Entry': 29.0748718,
#   'City': 'Troy',
#   'Female_Percentage': 0.6134,
#   'Institution_Name': 'Troy University',
#   'Latitude': 31.800128,
#   'Longitude': -85.950191,
#   'Male_Percentage': 0.3866,
#   'Number_Grad': 6075,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 970,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.91566075,
#   'Tuition_Cost': 14444,
#   'Unit_ID': 102368,
#   'Year': 2010,
#   'Zip': 36082},
#  '2010_102377': {'Admission_Rate': 0.5972,
#   'Age_Entry': 19.66509116,
#   'City': 'Tuskegee',
#   'Female_Percentage': 0.5645,
#   'Institution_Name': 'Tuskegee University',
#   'Latitude': 32.431021,
#   'Longitude': -85.710315,
#   'Male_Percentage': 0.4355,
#   'Number_Grad': 466,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 894,
#   'State': 'AL',
#   'Student_Loan_Percentage': 0.966239028,
#   'Tuition_Cost': 28752,
#   'Unit_ID': 102377,
#   'Year': 2010,
#   'Zip': 36088},
#  '2010_102395': {'Admission_Rate': -1.0,
#   'Age_Entry': 31.04273504,
#   'City': 'Daphne',
#   'Female_Percentage': 0.184,
#   'Institution_Name': 'United States Sports Academy',
#   'Latitude': 30.639329,
#   'Longitude': -87.91163,
#   'Male_Percentage': 0.816,
#   'Number_Grad': 380,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 102395,
#   'Year': 2010,
#   'Zip': 36526},
#  '2010_102429': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.67391304,
#   'City': 'Jasper',
#   'Female_Percentage': 0.6439,
#   'Institution_Name': 'Bevill State Community College',
#   'Latitude': 33.835785,
#   'Longitude': -87.265034,
#   'Male_Percentage': 0.3561,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'AL',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 12667,
#   'Unit_ID': 102429,
#   'Year': 2010,
#   'Zip': 35501},
#  '2010_102553': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.09427721,
#   'City': 'Anchorage',
#   'Female_Percentage': 0.5851,
#   'Institution_Name': 'University of Alaska Anchorage',
#   'Latitude': 61.189554,
#   'Longitude': -149.826135,
#   'Male_Percentage': 0.4149,
#   'Number_Grad': 1073,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.774892491,
#   'Tuition_Cost': 13693,
#   'Unit_ID': 102553,
#   'Year': 2010,
#   'Zip': 99508},
#  '2010_102614': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.69910847,
#   'City': 'Fairbanks',
#   'Female_Percentage': 0.568,
#   'Institution_Name': 'University of Alaska Fairbanks',
#   'Latitude': 64.856483,
#   'Longitude': -147.822943,
#   'Male_Percentage': 0.432,
#   'Number_Grad': 1203,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.760029718,
#   'Tuition_Cost': 14799,
#   'Unit_ID': 102614,
#   'Year': 2010,
#   'Zip': 99775},
#  '2010_102632': {'Admission_Rate': -1.0,
#   'Age_Entry': 27.88840263,
#   'City': 'Juneau',
#   'Female_Percentage': 0.6525,
#   'Institution_Name': 'University of Alaska Southeast',
#   'Latitude': 58.38427,
#   'Longitude': -134.636346,
#   'Male_Percentage': 0.3475,
#   'Number_Grad': 385,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.788840263,
#   'Tuition_Cost': 13531,
#   'Unit_ID': 102632,
#   'Year': 2010,
#   'Zip': 99801},
#  '2010_102669': {'Admission_Rate': 0.3346,
#   'Age_Entry': 29.46743295,
#   'City': 'Anchorage',
#   'Female_Percentage': 0.6517,
#   'Institution_Name': 'Alaska Pacific University',
#   'Latitude': 61.191235,
#   'Longitude': -149.804242,
#   'Male_Percentage': 0.3483,
#   'Number_Grad': 213,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': 1054,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.881226054,
#   'Tuition_Cost': 37760,
#   'Unit_ID': 102669,
#   'Year': 2010,
#   'Zip': 99508},
#  '2010_102711': {'Admission_Rate': 0.3311,
#   'Age_Entry': 26.81512605,
#   'City': 'Seward',
#   'Female_Percentage': 0.2481,
#   'Institution_Name': "AVTEC-Alaska's Institute of Technology",
#   'Latitude': 60.110727,
#   'Longitude': -149.444573,
#   'Male_Percentage': 0.7519,
#   'Number_Grad': -1,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.596638656,
#   'Tuition_Cost': -1,
#   'Unit_ID': 102711,
#   'Year': 2010,
#   'Zip': 99664},
#  '2010_102845': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.36528561,
#   'City': 'Vancouver',
#   'Female_Percentage': 0.7409,
#   'Institution_Name': 'Charter College',
#   'Latitude': 61.195786,
#   'Longitude': -149.840178,
#   'Male_Percentage': 0.2591,
#   'Number_Grad': -1,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'WA',
#   'Student_Loan_Percentage': 0.909291493,
#   'Tuition_Cost': 21540,
#   'Unit_ID': 102845,
#   'Year': 2010,
#   'Zip': 98683},
#  '2010_103361': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.09427721,
#   'City': 'Valdez',
#   'Female_Percentage': 0.6567,
#   'Institution_Name': 'Prince William Sound Community College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.3433,
#   'Number_Grad': -1,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.774892491,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103361,
#   'Year': 2010,
#   'Zip': 99686},
#  '2010_103501': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.36244542,
#   'City': 'Anchorage',
#   'Female_Percentage': 0.8313,
#   'Institution_Name': 'Alaska Career College',
#   'Latitude': 61.181443,
#   'Longitude': -149.856954,
#   'Male_Percentage': 0.1687,
#   'Number_Grad': -1,
#   'Region': 8,
#   'Region_Name': 'Far West',
#   'SAT_Avg': -1,
#   'State': 'AK',
#   'Student_Loan_Percentage': 0.838427948,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103501,
#   'Year': 2010,
#   'Zip': 99507},
#  '2010_103644': {'Admission_Rate': 0.4465,
#   'Age_Entry': 29.79796283,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.7428,
#   'Institution_Name': 'Everest College-Phoenix',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.2572,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.881129896,
#   'Tuition_Cost': 29445,
#   'Unit_ID': 103644,
#   'Year': 2010,
#   'Zip': 85021},
#  '2010_103723': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.40707786,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.2648,
#   'Institution_Name': 'Collins College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.7352,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.942366026,
#   'Tuition_Cost': 27723,
#   'Unit_ID': 103723,
#   'Year': 2010,
#   'Zip': 85040},
#  '2010_103732': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.81976744,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.9186,
#   'Institution_Name': 'Empire Beauty School-Paradise Valley',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.0814,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103732,
#   'Year': 2010,
#   'Zip': 85032},
#  '2010_103741': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.1617357,
#   'City': 'Tucson',
#   'Female_Percentage': 0.9329,
#   'Institution_Name': 'Empire Beauty School-Tucson',
#   'Latitude': 32.235657,
#   'Longitude': -110.927187,
#   'Male_Percentage': 0.0671,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.905325444,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103741,
#   'Year': 2010,
#   'Zip': 85716},
#  '2010_103778': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.52631579,
#   'City': 'Glendale',
#   'Female_Percentage': 1.0,
#   'Institution_Name': 'Thunderbird School of Global Management',
#   'Latitude': 33.620887,
#   'Longitude': -112.180861,
#   'Male_Percentage': 0.0,
#   'Number_Grad': 1308,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103778,
#   'Year': 2010,
#   'Zip': 85306},
#  '2010_103787': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.93055556,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.5,
#   'Institution_Name': 'American Indian College Inc',
#   'Latitude': 33.577738,
#   'Longitude': -112.092247,
#   'Male_Percentage': 0.5,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.638888889,
#   'Tuition_Cost': 18294,
#   'Unit_ID': 103787,
#   'Year': 2010,
#   'Zip': 85021},
#  '2010_103811': {'Admission_Rate': -1.0,
#   'Age_Entry': 39.01284473,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.088,
#   'Institution_Name': 'American Institute of Trucking',
#   'Latitude': 33.442262,
#   'Longitude': -112.175304,
#   'Male_Percentage': 0.912,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.986021912,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103811,
#   'Year': 2010,
#   'Zip': 85043},
#  '2010_103893': {'Admission_Rate': 1.0,
#   'Age_Entry': 27.3765375,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.8158,
#   'Institution_Name': 'Carrington College-Phoenix North',
#   'Latitude': 33.560821,
#   'Longitude': -112.115546,
#   'Male_Percentage': 0.1842,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.894590663,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103893,
#   'Year': 2010,
#   'Zip': 85051},
#  '2010_103909': {'Admission_Rate': 1.0,
#   'Age_Entry': 27.3765375,
#   'City': 'Mesa',
#   'Female_Percentage': 0.7834,
#   'Institution_Name': 'Carrington College-Mesa',
#   'Latitude': 33.39207,
#   'Longitude': -111.855281,
#   'Male_Percentage': 0.2166,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.894590663,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103909,
#   'Year': 2010,
#   'Zip': 85210},
#  '2010_103927': {'Admission_Rate': 1.0,
#   'Age_Entry': 27.3765375,
#   'City': 'Tucson',
#   'Female_Percentage': 0.7751,
#   'Institution_Name': 'Carrington College-Tucson',
#   'Latitude': 32.224,
#   'Longitude': -110.982961,
#   'Male_Percentage': 0.2249,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.894590663,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103927,
#   'Year': 2010,
#   'Zip': 85745},
#  '2010_103945': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.48617512,
#   'City': 'Flagstaff',
#   'Female_Percentage': 0.7939,
#   'Institution_Name': 'CollegeAmerica-Flagstaff',
#   'Latitude': 35.194607,
#   'Longitude': -111.65739,
#   'Male_Percentage': 0.2061,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.963133641,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103945,
#   'Year': 2010,
#   'Zip': 86001},
#  '2010_103954': {'Admission_Rate': -1.0,
#   'Age_Entry': 27.61946903,
#   'City': 'Tucson',
#   'Female_Percentage': 0.9277,
#   'Institution_Name': 'Arizona Academy of Beauty-East',
#   'Latitude': 32.237253,
#   'Longitude': -110.872305,
#   'Male_Percentage': 0.0723,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.884955752,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103954,
#   'Year': 2010,
#   'Zip': 85712},
#  '2010_103963': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.92983725,
#   'City': 'Glendale',
#   'Female_Percentage': 0.0623,
#   'Institution_Name': 'Arizona Automotive Institute',
#   'Latitude': 33.537249,
#   'Longitude': -112.157344,
#   'Male_Percentage': 0.9377,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.937432188,
#   'Tuition_Cost': -1,
#   'Unit_ID': 103963,
#   'Year': 2010,
#   'Zip': 85301},
#  '2010_104090': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.93461486,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.8331,
#   'Institution_Name': 'Brookline College-Phoenix',
#   'Latitude': 33.525384,
#   'Longitude': -112.15007,
#   'Male_Percentage': 0.1669,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.932042778,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104090,
#   'Year': 2010,
#   'Zip': 85021},
#  '2010_104151': {'Admission_Rate': 0.905,
#   'Age_Entry': 23.09761152,
#   'City': 'Tempe',
#   'Female_Percentage': 0.5086,
#   'Institution_Name': 'Arizona State University-Tempe',
#   'Latitude': 33.422247,
#   'Longitude': -111.934629,
#   'Male_Percentage': 0.4914,
#   'Number_Grad': 13878,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': 1077,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.878467299,
#   'Tuition_Cost': 18383,
#   'Unit_ID': 104151,
#   'Year': 2010,
#   'Zip': 85287},
#  '2010_104160': {'Admission_Rate': -1.0,
#   'Age_Entry': 24.68111736,
#   'City': 'Yuma',
#   'Female_Percentage': 0.569,
#   'Institution_Name': 'Arizona Western College',
#   'Latitude': 32.689306,
#   'Longitude': -114.495968,
#   'Male_Percentage': 0.431,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.157264647,
#   'Tuition_Cost': 12873,
#   'Unit_ID': 104160,
#   'Year': 2010,
#   'Zip': 85365},
#  '2010_104179': {'Admission_Rate': 0.7536,
#   'Age_Entry': 21.29344372,
#   'City': 'Tucson',
#   'Female_Percentage': 0.5219,
#   'Institution_Name': 'University of Arizona',
#   'Latitude': 32.232071,
#   'Longitude': -110.950769,
#   'Male_Percentage': 0.4781,
#   'Number_Grad': 8494,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': 1093,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.842783074,
#   'Tuition_Cost': 20537,
#   'Unit_ID': 104179,
#   'Year': 2010,
#   'Zip': 85721},
#  '2010_104188': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.27793696,
#   'City': 'Tucson',
#   'Female_Percentage': 0.5632,
#   'Institution_Name': 'Southwest University of Visual Arts-Tucson',
#   'Latitude': 32.252384,
#   'Longitude': -110.927321,
#   'Male_Percentage': 0.4368,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.931232092,
#   'Tuition_Cost': 46426,
#   'Unit_ID': 104188,
#   'Year': 2010,
#   'Zip': 85716},
#  '2010_104294': {'Admission_Rate': -1.0,
#   'Age_Entry': 24.57784431,
#   'City': 'Scottsdale',
#   'Female_Percentage': 0.8889,
#   'Institution_Name': 'Brillare Hairdressing Academy',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.1111,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.952095808,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104294,
#   'Year': 2010,
#   'Zip': 85254},
#  '2010_104346': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.36988028,
#   'City': 'Coolidge',
#   'Female_Percentage': 0.6078,
#   'Institution_Name': 'Central Arizona College',
#   'Latitude': 32.957092,
#   'Longitude': -111.652501,
#   'Male_Percentage': 0.3922,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.36441924,
#   'Tuition_Cost': 11276,
#   'Unit_ID': 104346,
#   'Year': 2010,
#   'Zip': 85128},
#  '2010_104364': {'Admission_Rate': -1.0,
#   'Age_Entry': 29.67371229,
#   'City': 'Tucson',
#   'Female_Percentage': 0.6,
#   'Institution_Name': 'Brown Mackie College-Tucson',
#   'Latitude': 32.236736,
#   'Longitude': -110.895086,
#   'Male_Percentage': 0.4,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.441617074,
#   'Tuition_Cost': 22010,
#   'Unit_ID': 104364,
#   'Year': 2010,
#   'Zip': 85712},
#  '2010_104391': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.12578616,
#   'City': 'Lake Havasu City',
#   'Female_Percentage': 0.9059,
#   'Institution_Name': 'Charles of Italy Beauty College',
#   'Latitude': 34.475275,
#   'Longitude': -114.328134,
#   'Male_Percentage': 0.0941,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.874213837,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104391,
#   'Year': 2010,
#   'Zip': 86403},
#  '2010_104425': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.19084296,
#   'City': 'Douglas',
#   'Female_Percentage': 0.562,
#   'Institution_Name': 'Cochise County Community College District',
#   'Latitude': 31.365757,
#   'Longitude': -109.690422,
#   'Male_Percentage': 0.438,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.237483954,
#   'Tuition_Cost': 8019,
#   'Unit_ID': 104425,
#   'Year': 2010,
#   'Zip': 85607},
#  '2010_104434': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.78084715,
#   'City': 'Flagstaff',
#   'Female_Percentage': 0.9355,
#   'Institution_Name': 'Empire Beauty School-Flagstaff',
#   'Latitude': 35.197151,
#   'Longitude': -111.625936,
#   'Male_Percentage': 0.0645,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.94106814,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104434,
#   'Year': 2010,
#   'Zip': 86004},
#  '2010_104443': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.78084715,
#   'City': 'Chandler',
#   'Female_Percentage': 0.913,
#   'Institution_Name': 'Empire Beauty School-Chandler',
#   'Latitude': 33.347586,
#   'Longitude': -111.860423,
#   'Male_Percentage': 0.087,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.94106814,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104443,
#   'Year': 2010,
#   'Zip': 85224},
#  '2010_104504': {'Admission_Rate': -1.0,
#   'Age_Entry': 31.40277778,
#   'City': 'Tucson',
#   'Female_Percentage': 0.7653,
#   'Institution_Name': 'Cortiva Institute-Tucson',
#   'Latitude': 32.21901,
#   'Longitude': -110.856785,
#   'Male_Percentage': 0.2347,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.949074074,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104504,
#   'Year': 2010,
#   'Zip': 85710},
#  '2010_104531': {'Admission_Rate': 0.6823,
#   'Age_Entry': 29.8048389,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.3016,
#   'Institution_Name': 'DeVry University-Arizona',
#   'Latitude': 33.56572,
#   'Longitude': -112.104961,
#   'Male_Percentage': 0.6984,
#   'Number_Grad': 580,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.940064678,
#   'Tuition_Cost': 29922,
#   'Unit_ID': 104531,
#   'Year': 2010,
#   'Zip': 85021},
#  '2010_104568': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.112529,
#   'City': 'Mesa',
#   'Female_Percentage': 0.9688,
#   'Institution_Name': 'Avalon School of Cosmetology-Mesa',
#   'Latitude': 33.376583,
#   'Longitude': -111.858305,
#   'Male_Percentage': 0.0313,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.908352668,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104568,
#   'Year': 2010,
#   'Zip': 85210},
#  '2010_104577': {'Admission_Rate': -1.0,
#   'Age_Entry': 25.72383587,
#   'City': 'Thatcher',
#   'Female_Percentage': 0.5313,
#   'Institution_Name': 'Eastern Arizona College',
#   'Latitude': 32.840719,
#   'Longitude': -109.761664,
#   'Male_Percentage': 0.4688,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 10501,
#   'Unit_ID': 104577,
#   'Year': 2010,
#   'Zip': 85552},
#  '2010_104586': {'Admission_Rate': 0.8193,
#   'Age_Entry': 25.76723277,
#   'City': 'Prescott',
#   'Female_Percentage': 0.173,
#   'Institution_Name': 'Embry-Riddle Aeronautical University-Prescott',
#   'Latitude': 34.615678,
#   'Longitude': -112.452285,
#   'Male_Percentage': 0.827,
#   'Number_Grad': 51,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': 1130,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.810989011,
#   'Tuition_Cost': 41586,
#   'Unit_ID': 104586,
#   'Year': 2010,
#   'Zip': 86301},
#  '2010_104665': {'Admission_Rate': -1.0,
#   'Age_Entry': -2.0,
#   'City': 'Scottsdale',
#   'Female_Percentage': 0.375,
#   'Institution_Name': 'Frank Lloyd Wright School of Architecture',
#   'Latitude': 33.60715,
#   'Longitude': -111.846477,
#   'Male_Percentage': 0.625,
#   'Number_Grad': 21,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 104665,
#   'Year': 2010,
#   'Zip': 85259},
#  '2010_104708': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.01171842,
#   'City': 'Glendale',
#   'Female_Percentage': 0.5301,
#   'Institution_Name': 'Glendale Community College',
#   'Latitude': 33.567483,
#   'Longitude': -112.188334,
#   'Male_Percentage': 0.4699,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.48088273,
#   'Tuition_Cost': 11525,
#   'Unit_ID': 104708,
#   'Year': 2010,
#   'Zip': 85302},
#  '2010_104717': {'Admission_Rate': 1.0,
#   'Age_Entry': 34.53334804,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.7636,
#   'Institution_Name': 'Grand Canyon University',
#   'Latitude': 33.512172,
#   'Longitude': -112.129917,
#   'Male_Percentage': 0.2364,
#   'Number_Grad': 15783,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
#   'Student_Loan_Percentage': 0.917330897,
#   'Tuition_Cost': 32486,
#   'Unit_ID': 104717,
#   'Year': 2010,
#   'Zip': 85017},
#  '2010_104805': {'Admission_Rate': -1.0,
#   'Age_Entry': 30.66859014,
#   'City': 'Phoenix',
#   'Female_Percentage': 0.7706,
#   'Institution_Name': 'Anthem College-Phoenix',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.2294,
#   'Number_Grad': -1,
#   'Region': 6,
#   'Region_Name': 'Southwest',
#   'SAT_Avg': -1,
#   'State': 'AZ',
# ...
#   'Zip': 31088},
#  '2010_140146': {'Admission_Rate': -1.0,
#   'Age_Entry': -2.0,
#   'City': 'Atlanta',
#   'Female_Percentage': -1.0,
#   'Institution_Name': 'Interdenominational Theological Center',
#   'Latitude': 33.754904,
#   'Longitude': -84.410337,
#   'Male_Percentage': -1.0,
#   'Number_Grad': 411,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 140146,
#   'Year': 2010,
#   'Zip': 30314},
#  '2010_140164': {'Admission_Rate': 0.636,
#   'Age_Entry': 24.01155235,
#   'City': 'Kennesaw',
#   'Female_Percentage': 0.5875,
#   'Institution_Name': 'Kennesaw State University',
#   'Latitude': 34.032662,
#   'Longitude': -84.580393,
#   'Male_Percentage': 0.4125,
#   'Number_Grad': 1985,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1060,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.855776173,
#   'Tuition_Cost': 17490,
#   'Unit_ID': 140164,
#   'Year': 2010,
#   'Zip': 30144},
#  '2010_140234': {'Admission_Rate': 0.5791,
#   'Age_Entry': 23.24150268,
#   'City': 'Lagrange',
#   'Female_Percentage': 0.5774,
#   'Institution_Name': 'LaGrange College',
#   'Latitude': 33.039713,
#   'Longitude': -85.041394,
#   'Male_Percentage': 0.4226,
#   'Number_Grad': 160,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1024,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.953488372,
#   'Tuition_Cost': 32770,
#   'Unit_ID': 140234,
#   'Year': 2010,
#   'Zip': 30240},
#  '2010_140243': {'Admission_Rate': -1.0,
#   'Age_Entry': 31.30003887,
#   'City': 'Oakwood',
#   'Female_Percentage': 0.6395,
#   'Institution_Name': 'Lanier Technical College',
#   'Latitude': 34.236386,
#   'Longitude': -83.864559,
#   'Male_Percentage': 0.3605,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 13001,
#   'Unit_ID': 140243,
#   'Year': 2010,
#   'Zip': 30566},
#  '2010_140252': {'Admission_Rate': 0.6117,
#   'Age_Entry': 27.4718982,
#   'City': 'Marietta',
#   'Female_Percentage': 0.5126,
#   'Institution_Name': 'Life University',
#   'Latitude': 33.932104,
#   'Longitude': -84.514156,
#   'Male_Percentage': 0.4874,
#   'Number_Grad': 1645,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 903,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.978791092,
#   'Tuition_Cost': 24414,
#   'Unit_ID': 140252,
#   'Year': 2010,
#   'Zip': 30060},
#  '2010_140304': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.85352074,
#   'City': 'Macon',
#   'Female_Percentage': 0.6597,
#   'Institution_Name': 'Central Georgia Technical College',
#   'Latitude': 32.54502,
#   'Longitude': -83.667531,
#   'Male_Percentage': 0.3403,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.114510128,
#   'Tuition_Cost': 7924,
#   'Unit_ID': 140304,
#   'Year': 2010,
#   'Zip': 31206},
#  '2010_140322': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.03423968,
#   'City': 'Macon',
#   'Female_Percentage': 0.6587,
#   'Institution_Name': 'Macon State College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.3413,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.643252769,
#   'Tuition_Cost': 3368,
#   'Unit_ID': 140322,
#   'Year': 2010,
#   'Zip': 31206},
#  '2010_140331': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.8862659,
#   'City': 'Marietta',
#   'Female_Percentage': 0.6016,
#   'Institution_Name': 'Chattahoochee Technical College',
#   'Latitude': 33.929093,
#   'Longitude': -84.552492,
#   'Male_Percentage': 0.3984,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 12426,
#   'Unit_ID': 140331,
#   'Year': 2010,
#   'Zip': 30060},
#  '2010_140340': {'Admission_Rate': 0.7917,
#   'Age_Entry': 31.23799859,
#   'City': 'Atlanta',
#   'Female_Percentage': 0.6556,
#   'Institution_Name': 'Herzing University-Atlanta',
#   'Latitude': 33.846627,
#   'Longitude': -84.362635,
#   'Male_Percentage': 0.3444,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.828715143,
#   'Tuition_Cost': 31296,
#   'Unit_ID': 140340,
#   'Year': 2010,
#   'Zip': 30326},
#  '2010_140401': {'Admission_Rate': -1.0,
#   'Age_Entry': 24.97954546,
#   'City': 'Augusta',
#   'Female_Percentage': 0.8769,
#   'Institution_Name': 'Georgia Health Sciences University',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.1231,
#   'Number_Grad': 1962,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.485606061,
#   'Tuition_Cost': -1,
#   'Unit_ID': 140401,
#   'Year': 2010,
#   'Zip': 30912},
#  '2010_140447': {'Admission_Rate': 0.6395,
#   'Age_Entry': 28.090301,
#   'City': 'Macon',
#   'Female_Percentage': 0.6733,
#   'Institution_Name': 'Mercer University',
#   'Latitude': 32.831709,
#   'Longitude': -83.650114,
#   'Male_Percentage': 0.3267,
#   'Number_Grad': 3727,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1182,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.954013378,
#   'Tuition_Cost': 41529,
#   'Unit_ID': 140447,
#   'Year': 2010,
#   'Zip': 31207},
#  '2010_140483': {'Admission_Rate': 0.8853,
#   'Age_Entry': 23.77650298,
#   'City': 'Cochran',
#   'Female_Percentage': 0.5435,
#   'Institution_Name': 'Middle Georgia College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.4565,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.625975218,
#   'Tuition_Cost': 11050,
#   'Unit_ID': 140483,
#   'Year': 2010,
#   'Zip': 31014},
#  '2010_140553': {'Admission_Rate': 0.6383,
#   'Age_Entry': 19.86352559,
#   'City': 'Atlanta',
#   'Female_Percentage': 0.0,
#   'Institution_Name': 'Morehouse College',
#   'Latitude': 33.74793,
#   'Longitude': -84.415156,
#   'Male_Percentage': 1.0,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1030,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.956945573,
#   'Tuition_Cost': 39122,
#   'Unit_ID': 140553,
#   'Year': 2010,
#   'Zip': 30314},
#  '2010_140562': {'Admission_Rate': -1.0,
#   'Age_Entry': -2.0,
#   'City': 'Atlanta',
#   'Female_Percentage': -1.0,
#   'Institution_Name': 'Morehouse School of Medicine',
#   'Latitude': 33.742549,
#   'Longitude': -84.411958,
#   'Male_Percentage': -1.0,
#   'Number_Grad': 329,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 140562,
#   'Year': 2010,
#   'Zip': 30310},
#  '2010_140599': {'Admission_Rate': -1.0,
#   'Age_Entry': 29.17326733,
#   'City': 'Moultrie',
#   'Female_Percentage': 0.636,
#   'Institution_Name': 'Moultrie Technical College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.364,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 13650,
#   'Unit_ID': 140599,
#   'Year': 2010,
#   'Zip': 31788},
#  '2010_140669': {'Admission_Rate': 0.5602,
#   'Age_Entry': 22.66946138,
#   'City': 'Dahlonega',
#   'Female_Percentage': 0.5635,
#   'Institution_Name': 'University of North Georgia',
#   'Latitude': 34.530527,
#   'Longitude': -83.986574,
#   'Male_Percentage': 0.4365,
#   'Number_Grad': 559,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1093,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.635670732,
#   'Tuition_Cost': 13439,
#   'Unit_ID': 140669,
#   'Year': 2010,
#   'Zip': 30597},
#  '2010_140678': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.80276286,
#   'City': 'Clarkesville',
#   'Female_Percentage': 0.5925,
#   'Institution_Name': 'North Georgia Technical College',
#   'Latitude': 34.63853,
#   'Longitude': -83.529592,
#   'Male_Percentage': 0.4075,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.098234843,
#   'Tuition_Cost': 13954,
#   'Unit_ID': 140678,
#   'Year': 2010,
#   'Zip': 30523},
#  '2010_140696': {'Admission_Rate': 0.8641,
#   'Age_Entry': 23.16312057,
#   'City': 'Atlanta',
#   'Female_Percentage': 0.603,
#   'Institution_Name': 'Oglethorpe University',
#   'Latitude': 33.875939,
#   'Longitude': -84.334756,
#   'Male_Percentage': 0.397,
#   'Number_Grad': 72,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1142,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.916666667,
#   'Tuition_Cost': 40290,
#   'Unit_ID': 140696,
#   'Year': 2010,
#   'Zip': 30319},
#  '2010_140720': {'Admission_Rate': 0.4111,
#   'Age_Entry': 20.85875706,
#   'City': 'Augusta',
#   'Female_Percentage': 0.6427,
#   'Institution_Name': 'Paine College',
#   'Latitude': 33.469259,
#   'Longitude': -81.991199,
#   'Male_Percentage': 0.3573,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 757,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.956214689,
#   'Tuition_Cost': 21014,
#   'Unit_ID': 140720,
#   'Year': 2010,
#   'Zip': 30901},
#  '2010_140818': {'Admission_Rate': 0.6114,
#   'Age_Entry': 26.17249698,
#   'City': 'Demorest',
#   'Female_Percentage': 0.6927,
#   'Institution_Name': 'Piedmont College',
#   'Latitude': 34.56663,
#   'Longitude': -83.543216,
#   'Male_Percentage': 0.3073,
#   'Number_Grad': 1420,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1030,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.945717732,
#   'Tuition_Cost': 28200,
#   'Unit_ID': 140818,
#   'Year': 2010,
#   'Zip': 30535},
#  '2010_140827': {'Admission_Rate': 0.8158,
#   'Age_Entry': 26.83962264,
#   'City': 'Atlanta',
#   'Female_Percentage': 0.5728,
#   'Institution_Name': 'Portfolio Center',
#   'Latitude': 33.811882,
#   'Longitude': -84.39589,
#   'Male_Percentage': 0.4272,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 31775,
#   'Unit_ID': 140827,
#   'Year': 2010,
#   'Zip': 30309},
#  '2010_140872': {'Admission_Rate': 0.5792,
#   'Age_Entry': 24.42690059,
#   'City': 'Waleska',
#   'Female_Percentage': 0.5702,
#   'Institution_Name': 'Reinhardt University',
#   'Latitude': 34.318874,
#   'Longitude': -84.554657,
#   'Male_Percentage': 0.4298,
#   'Number_Grad': 117,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 996,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.903508772,
#   'Tuition_Cost': 27990,
#   'Unit_ID': 140872,
#   'Year': 2010,
#   'Zip': 30183},
#  '2010_140942': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.10333066,
#   'City': 'Savannah',
#   'Female_Percentage': 0.6672,
#   'Institution_Name': 'Savannah Technical College',
#   'Latitude': 32.023211,
#   'Longitude': -81.114753,
#   'Male_Percentage': 0.3328,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.080256822,
#   'Tuition_Cost': 8774,
#   'Unit_ID': 140942,
#   'Year': 2010,
#   'Zip': 31405},
#  '2010_140951': {'Admission_Rate': 0.6261,
#   'Age_Entry': 21.30002636,
#   'City': 'Savannah',
#   'Female_Percentage': 0.614,
#   'Institution_Name': 'Savannah College of Art and Design',
#   'Latitude': 32.072966,
#   'Longitude': -81.093905,
#   'Male_Percentage': 0.386,
#   'Number_Grad': 1968,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1073,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.969680991,
#   'Tuition_Cost': 43609,
#   'Unit_ID': 140951,
#   'Year': 2010,
#   'Zip': 31402},
#  '2010_140960': {'Admission_Rate': -1.0,
#   'Age_Entry': 20.98097087,
#   'City': 'Savannah',
#   'Female_Percentage': 0.5504,
#   'Institution_Name': 'Savannah State University',
#   'Latitude': 32.024781,
#   'Longitude': -81.063377,
#   'Male_Percentage': 0.4496,
#   'Number_Grad': 139,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.94368932,
#   'Tuition_Cost': 13966,
#   'Unit_ID': 140960,
#   'Year': 2010,
#   'Zip': 31404},
#  '2010_140988': {'Admission_Rate': 0.6225,
#   'Age_Entry': 31.53566906,
#   'City': 'Rome',
#   'Female_Percentage': 0.5166,
#   'Institution_Name': 'Shorter University',
#   'Latitude': 34.258192,
#   'Longitude': -85.196213,
#   'Male_Percentage': 0.4834,
#   'Number_Grad': 13,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 970,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.952722668,
#   'Tuition_Cost': 26512,
#   'Unit_ID': 140988,
#   'Year': 2010,
#   'Zip': 30165},
#  '2010_140997': {'Admission_Rate': 0.5805,
#   'Age_Entry': 22.77665762,
#   'City': 'Douglas',
#   'Female_Percentage': 0.6099,
#   'Institution_Name': 'South Georgia College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.3901,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 845,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.628150446,
#   'Tuition_Cost': 10511,
#   'Unit_ID': 140997,
#   'Year': 2010,
#   'Zip': 31533},
#  '2010_141006': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.59898675,
#   'City': 'Americus',
#   'Female_Percentage': 0.53,
#   'Institution_Name': 'South Georgia Technical College',
#   'Latitude': 32.116663,
#   'Longitude': -84.188321,
#   'Male_Percentage': 0.47,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 9458,
#   'Unit_ID': 141006,
#   'Year': 2010,
#   'Zip': 31709},
#  '2010_141015': {'Admission_Rate': -1.0,
#   'Age_Entry': 26.4,
#   'City': 'Atlanta',
#   'Female_Percentage': 0.4791,
#   'Institution_Name': 'The Creative Circus',
#   'Latitude': 33.813156,
#   'Longitude': -84.361989,
#   'Male_Percentage': 0.5209,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': -1,
#   'Unit_ID': 141015,
#   'Year': 2010,
#   'Zip': 30324},
#  '2010_141060': {'Admission_Rate': 0.3764,
#   'Age_Entry': 19.80392157,
#   'City': 'Atlanta',
#   'Female_Percentage': 1.0,
#   'Institution_Name': 'Spelman College',
#   'Latitude': 33.74519,
#   'Longitude': -84.410118,
#   'Male_Percentage': 0.0,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1035,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.951871658,
#   'Tuition_Cost': 36488,
#   'Unit_ID': 141060,
#   'Year': 2010,
#   'Zip': 30314},
#  '2010_141097': {'Admission_Rate': 0.7447,
#   'Age_Entry': 24.60750422,
#   'City': 'Marietta',
#   'Female_Percentage': 0.1908,
#   'Institution_Name': 'Southern Polytechnic State University',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.8092,
#   'Number_Grad': 702,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1115,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.8693086,
#   'Tuition_Cost': 14541,
#   'Unit_ID': 141097,
#   'Year': 2010,
#   'Zip': 30060},
#  '2010_141158': {'Admission_Rate': -1.0,
#   'Age_Entry': 28.46531038,
#   'City': 'Thomasville',
#   'Female_Percentage': 0.6713,
#   'Institution_Name': 'Southwest Georgia Technical College',
#   'Latitude': -1.0,
#   'Longitude': -1.0,
#   'Male_Percentage': 0.3287,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': -2.0,
#   'Tuition_Cost': 9504,
#   'Unit_ID': 141158,
#   'Year': 2010,
#   'Zip': 31792},
#  '2010_141167': {'Admission_Rate': -1.0,
#   'Age_Entry': 30.83306056,
#   'City': 'Thomasville',
#   'Female_Percentage': 0.6338,
#   'Institution_Name': 'Thomas University',
#   'Latitude': 30.813954,
#   'Longitude': -83.981478,
#   'Male_Percentage': 0.3662,
#   'Number_Grad': 194,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': -1,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.926350246,
#   'Tuition_Cost': 22835,
#   'Unit_ID': 141167,
#   'Year': 2010,
#   'Zip': 31792},
#  '2010_141185': {'Admission_Rate': 0.5465,
#   'Age_Entry': 21.79035639,
#   'City': 'Toccoa Falls',
#   'Female_Percentage': 0.5309,
#   'Institution_Name': 'Toccoa Falls College',
#   'Latitude': 34.59554,
#   'Longitude': -83.353462,
#   'Male_Percentage': 0.4691,
#   'Number_Grad': -1,
#   'Region': 5,
#   'Region_Name': 'Southeast',
#   'SAT_Avg': 1005,
#   'State': 'GA',
#   'Student_Loan_Percentage': 0.890985325,
#   'Tuition_Cost': 27237,
#   'Unit_ID': 141185,
#   'Year': 2010,
#   'Zip': 30598},
#  ...}
